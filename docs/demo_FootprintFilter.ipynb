# %% [markdown]
# # LSST Camera Footprint Filter Demo
#
# This notebook demonstrates the LSST camera footprint filter for LSST opsim based survey simulations (http://astro-lsst-01.astro.washington.edu:8080/) and the output of the JPL based solar system object survey simulator (https://github.com/dirac-institute/survey_simulator).

# %%
from sorcha.modules import PPFootprintFilter as fp

# %%
import pandas as pd
import sqlite3 as sql
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
def getSqlData(database,rows_start,nrows):
    """Import dataset from local SQL database
    
    Parameters:
    -----------
    database   ... path to database
    rows_start ... number of row to start
    rows_max   ... number of rows to select
    
    Returns:
    --------
    observations ... pandas dataframe containing observations from JPL database
    """
    con = sql.connect(database)
    observations = pd.read_sql("""SELECT * FROM observations LIMIT """+str(rows_start)+','+str(nrows), con)
    return observations

# %% [markdown]
# ## Import LSST Opsim database
# This database contains LSST pointings and environmental information such as seeing.

# %%
db_path = "oneline_v2.0.db"

# %% [markdown]
# Select the first ten exposures of the LSST survey for testing purposes.

# %%
LSSTdf = getSqlData(db_path,0,1)

# %%
LSSTdf
# Out:
#    observationId     fieldRA   fieldDec  observationStartMJD  flush_by_mjd  \
# 0         402942  273.428988 -24.927018         60945.035513  60945.046343
#
#    visitExposureTime filter   rotSkyPos  numExposures   airmass  ...  \
# 0               30.0      r  182.732823             2  1.167313  ...
#
#        moonAz       sunAz     sunRA    sunDec      moonRA    moonDec  \
# 0  255.879834  249.525893  3.202872 -0.026538  237.159818 -25.033311
#
#    moonDistance  solarElong  moonPhase  cummTelAz
# 0     32.775376   89.284813  31.535417 -60.379656
#
# [1 rows x 41 columns]

# %% [markdown]
# ## Grab simulated observations

# %%
dfobs = pd.read_csv("footprintFilterValidationObservations.csv", delim_whitespace=True)

# %%
dfobs
# Out:
#             ObjID   FieldID  FieldMJD_TAI  AstRange(km)  AstRangeRate(km/s)  \
# 0       S0000w6ca  402942.0  60945.035513   344266000.0            9.645862
# 1       S0000wkZa  402942.0  60945.035513    93728970.0           24.810874
# 2       S0000wspa  402942.0  60945.035513   330569600.0           21.915557
# 3       S0000wUea  402942.0  60945.035513   492613400.0           25.078801
# 4       S0000xl3a  402942.0  60945.035513   200278800.0           30.796080
# ...           ...       ...           ...           ...                 ...
# 29051  mpc00K8271  402942.0  60945.035513   360725700.0           20.617454
# 29052  mpc00K9056  402942.0  60945.035513   261587100.0           16.465273
# 29053  mpc00K9551  402942.0  60945.035513   298658200.0           16.740250
# 29054  mpc00K9617  402942.0  60945.035513   371087000.0           21.670828
# 29055  mpc00K9664  402942.0  60945.035513   252349900.0           18.731995
#
#        AstRA(deg)  AstRARate(deg/day)  AstDec(deg)  AstDecRate(deg/day)  \
# 0      273.950475            0.145419   -25.409570            -0.034414
# 1      273.029493            1.592210   -24.398177            -0.243588
# 2      274.480023            0.072605   -25.283050             0.093505
# 3      273.646543            0.109090   -25.456436             0.005462
# 4      271.853254            0.734379   -23.453650            -0.003425
# ...           ...                 ...          ...                  ...
# 29051  272.594036            0.244908   -25.480627             0.015066
# 29052  272.172454            0.412457   -25.517282             0.032230
# 29053  274.477149            0.288844   -26.376947             0.009252
# 29054  272.019401            0.241333   -24.188684             0.022293
# 29055  275.385502            0.430778   -25.443011             0.025301
#
#        Ast-Sun(J2000x)(km)  ...  Ast-Sun(J2000vz)(km/s)  Obs-Sun(J2000x)(km)  \
# 0              171050400.0  ...                5.477871          149626900.0
# 1              154138100.0  ...               -2.670822          149626900.0
# 2              172974700.0  ...                8.064873          149626900.0
# 3              177915900.0  ...                1.489699          149626900.0
# 4              155568800.0  ...               -0.605902          149626900.0
# ...                    ...  ...                     ...                  ...
# 29051          164365000.0  ...                3.899935          149626900.0
# 29052          158575700.0  ...                6.222693          149626900.0
# 29053          170513400.0  ...                4.841374          149626900.0
# 29054          161555100.0  ...                4.423580          149626900.0
# 29055          171014400.0  ...                4.895786          149626900.0
#
#        Obs-Sun(J2000y)(km)  Obs-Sun(J2000z)(km)  Obs-Sun(J2000vx)(km/s)  \
# 0                9189664.0            3981839.0               -2.165552
# 1                9189664.0            3981839.0               -2.165552
# 2                9189664.0            3981839.0               -2.165552
# 3                9189664.0            3981839.0               -2.165552
# 4                9189664.0            3981839.0               -2.165552
# ...                    ...                  ...                     ...
# 29051            9189664.0            3981839.0               -2.165552
# 29052            9189664.0            3981839.0               -2.165552
# 29053            9189664.0            3981839.0               -2.165552
# 29054            9189664.0            3981839.0               -2.165552
# 29055            9189664.0            3981839.0               -2.165552
#
#        Obs-Sun(J2000vy)(km/s)  Obs-Sun(J2000vz)(km/s)  Sun-Ast-Obs(deg)  \
# 0                   27.419133               11.778333         23.579048
# 1                   27.419133               11.778333         58.765271
# 2                   27.419133               11.778333         24.363095
# 3                   27.419133               11.778333         16.976109
# 4                   27.419133               11.778333         37.584025
# ...                       ...                     ...               ...
# 29051               27.419133               11.778333         22.787741
# 29052               27.419133               11.778333         30.279516
# 29053               27.419133               11.778333         26.624500
# 29054               27.419133               11.778333         22.274549
# 29055               27.419133               11.778333         30.449283
#
#                V    V(H=0)
# 0      28.916485  4.915485
# 1      25.451943  1.441943
# 2      28.799210  4.784210
# 3      30.199404  6.167404
# 4      27.273330  3.225330
# ...          ...       ...
# 29051  22.312084  5.062084
# 29052  21.032581  4.012581
# 29053  21.221274  4.451274
# 29054  22.124108  5.154108
# 29055  20.619203  3.929203
#
# [29056 rows x 24 columns]

# %% [markdown]
# These observations all lie on a circle of radius 2.1deg.

# %%
plt.figure(dpi=150,figsize=(6,6))
plt.scatter(dfobs['AstRA(deg)'],dfobs['AstDec(deg)'],s=0.1)
plt.show()

# %%
dfobs = pd.merge(dfobs, LSSTdf, left_on="FieldID", right_on="observationId", how="left")

# %% [markdown]
# ## Test footprint filter

# %%
camera = fp.Footprint("detectors_corners.csv")

# %%
df_new=camera.applyFootprint(dfobs)

# %%
dfobs_in_fp = dfobs.iloc[df_new[0]]

# %%
dfobs_in_fp
# Out:
#             ObjID   FieldID  FieldMJD_TAI  AstRange(km)  AstRangeRate(km/s)  \
# 184     S0000qEoa  402942.0  60945.035513   387445900.0           24.937591
# 374     S1001Q51a  402942.0  60945.035513   406746600.0           23.471586
# 448     S1006IoOa  402942.0  60945.035513   317372700.0           19.818773
# 538     S1000Ks7a  402942.0  60945.035513   346006200.0           23.300574
# 773     S1006rEca  402942.0  60945.035513   393096900.0           20.805666
# ...           ...       ...           ...           ...                 ...
# 27426  mpcK17B32N  402942.0  60945.035513   110491500.0            5.913646
# 27821  mpcK12DA8D  402942.0  60945.035513   347987400.0           24.193037
# 28384  mpcK16A35J  402942.0  60945.035513   384200300.0           22.344931
# 28808  mpcK14Wr0K  402942.0  60945.035513   410177600.0           24.292635
# 28891  mpc00P6249  402942.0  60945.035513   393297400.0           26.579987
#
#        AstRA(deg)  AstRARate(deg/day)  AstDec(deg)  AstDecRate(deg/day)  \
# 184    274.368502            0.140563   -23.230652             0.005002
# 374    274.255988            0.214356   -23.310009            -0.004073
# 448    274.444716            0.272782   -23.345640            -0.018433
# 538    274.429778            0.254463   -23.156810             0.014485
# 773    274.283327            0.201285   -23.226368             0.016283
# ...           ...                 ...          ...                  ...
# 27426  272.495186            0.581329   -26.689091            -0.086678
# 27821  272.577922            0.304269   -26.678877             0.043013
# 28384  272.483062            0.224164   -26.507794            -0.027891
# 28808  272.582601            0.217256   -26.649959             0.054629
# 28891  272.530382            0.249512   -26.530097             0.006841
#
#        Ast-Sun(J2000x)(km)  ...      moonAz       sunAz     sunRA    sunDec  \
# 184            176746300.0  ...  255.879834  249.525893  3.202872 -0.026538
# 374            177348800.0  ...  255.879834  249.525893  3.202872 -0.026538
# 448            172208800.0  ...  255.879834  249.525893  3.202872 -0.026538
# 538            174198300.0  ...  255.879834  249.525893  3.202872 -0.026538
# 773            176607200.0  ...  255.879834  249.525893  3.202872 -0.026538
# ...                    ...  ...         ...         ...       ...       ...
# 27426          153924700.0  ...  255.879834  249.525893  3.202872 -0.026538
# 27821          163612400.0  ...  255.879834  249.525893  3.202872 -0.026538
# 28384          164522200.0  ...  255.879834  249.525893  3.202872 -0.026538
# 28808          166145800.0  ...  255.879834  249.525893  3.202872 -0.026538
# 28891          165162200.0  ...  255.879834  249.525893  3.202872 -0.026538
#
#            moonRA    moonDec  moonDistance  solarElong  moonPhase  cummTelAz
# 184    237.159818 -25.033311     32.775376   89.284813  31.535417 -60.379656
# 374    237.159818 -25.033311     32.775376   89.284813  31.535417 -60.379656
# 448    237.159818 -25.033311     32.775376   89.284813  31.535417 -60.379656
# 538    237.159818 -25.033311     32.775376   89.284813  31.535417 -60.379656
# 773    237.159818 -25.033311     32.775376   89.284813  31.535417 -60.379656
# ...           ...        ...           ...         ...        ...        ...
# 27426  237.159818 -25.033311     32.775376   89.284813  31.535417 -60.379656
# 27821  237.159818 -25.033311     32.775376   89.284813  31.535417 -60.379656
# 28384  237.159818 -25.033311     32.775376   89.284813  31.535417 -60.379656
# 28808  237.159818 -25.033311     32.775376   89.284813  31.535417 -60.379656
# 28891  237.159818 -25.033311     32.775376   89.284813  31.535417 -60.379656
#
# [19955 rows x 65 columns]

# %%
plt.figure(figsize=(15, 15))
plt.scatter(dfobs_in_fp['AstRA(deg)'],dfobs_in_fp['AstDec(deg)'],s=1.)
plt.show()
