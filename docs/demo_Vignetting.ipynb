# %% [markdown]
# ## Vignetting Demo

# %% [markdown]
# This notebook demonstrates the adjustment of limiting magnitude at the object position to account for vignetting.

# %%
import pandas as pd
import sqlite3 as sql
import matplotlib.pyplot as plt

# %%
from sorcha.modules.PPVignetting import vignettingEffects

# %% [markdown]
# We begin by loading in a set of randomised artificial observations which were all generated to lie on the same field, within 2.1 degrees of field centre. To begin with, these observations all have the same five sigma depth at source, or limiting magnitude.

# %%
def get_sql_data(database, rows_start, nrows):
    
    con = sql.connect(database)
    observations = pd.read_sql("""SELECT * FROM observations LIMIT """ + str(rows_start) + ',' + str(nrows), con)
    
    return observations

# %%
db_path = "oneline_v2.0.db"
LSSTdf = get_sql_data(db_path, 0,1)

# %%
dfobs = pd.read_csv("footprintFilterValidationObservations.csv", delim_whitespace=True)

# %%
dfobs = pd.merge(dfobs, LSSTdf, left_on="FieldID", right_on="observationId", how="left")

# %%
dfobs
# Out:
#             ObjID   FieldID  FieldMJD_TAI  AstRange(km)  AstRangeRate(km/s)  \
# 0       S0000w6ca  402942.0  60945.035513   344266000.0            9.645862
# 1       S0000wkZa  402942.0  60945.035513    93728970.0           24.810874
# 2       S0000wspa  402942.0  60945.035513   330569600.0           21.915557
# 3       S0000wUea  402942.0  60945.035513   492613400.0           25.078801
# 4       S0000xl3a  402942.0  60945.035513   200278800.0           30.796080
# ...           ...       ...           ...           ...                 ...
# 29051  mpc00K8271  402942.0  60945.035513   360725700.0           20.617454
# 29052  mpc00K9056  402942.0  60945.035513   261587100.0           16.465273
# 29053  mpc00K9551  402942.0  60945.035513   298658200.0           16.740250
# 29054  mpc00K9617  402942.0  60945.035513   371087000.0           21.670828
# 29055  mpc00K9664  402942.0  60945.035513   252349900.0           18.731995
#
#        AstRA(deg)  AstRARate(deg/day)  AstDec(deg)  AstDecRate(deg/day)  \
# 0      273.950475            0.145419   -25.409570            -0.034414
# 1      273.029493            1.592210   -24.398177            -0.243588
# 2      274.480023            0.072605   -25.283050             0.093505
# 3      273.646543            0.109090   -25.456436             0.005462
# 4      271.853254            0.734379   -23.453650            -0.003425
# ...           ...                 ...          ...                  ...
# 29051  272.594036            0.244908   -25.480627             0.015066
# 29052  272.172454            0.412457   -25.517282             0.032230
# 29053  274.477149            0.288844   -26.376947             0.009252
# 29054  272.019401            0.241333   -24.188684             0.022293
# 29055  275.385502            0.430778   -25.443011             0.025301
#
#        Ast-Sun(J2000x)(km)  ...      moonAz       sunAz     sunRA    sunDec  \
# 0              171050400.0  ...  255.879834  249.525893  3.202872 -0.026538
# 1              154138100.0  ...  255.879834  249.525893  3.202872 -0.026538
# 2              172974700.0  ...  255.879834  249.525893  3.202872 -0.026538
# 3              177915900.0  ...  255.879834  249.525893  3.202872 -0.026538
# 4              155568800.0  ...  255.879834  249.525893  3.202872 -0.026538
# ...                    ...  ...         ...         ...       ...       ...
# 29051          164365000.0  ...  255.879834  249.525893  3.202872 -0.026538
# 29052          158575700.0  ...  255.879834  249.525893  3.202872 -0.026538
# 29053          170513400.0  ...  255.879834  249.525893  3.202872 -0.026538
# 29054          161555100.0  ...  255.879834  249.525893  3.202872 -0.026538
# 29055          171014400.0  ...  255.879834  249.525893  3.202872 -0.026538
#
#            moonRA    moonDec  moonDistance  solarElong  moonPhase  cummTelAz
# 0      237.159818 -25.033311     32.775376   89.284813  31.535417 -60.379656
# 1      237.159818 -25.033311     32.775376   89.284813  31.535417 -60.379656
# 2      237.159818 -25.033311     32.775376   89.284813  31.535417 -60.379656
# 3      237.159818 -25.033311     32.775376   89.284813  31.535417 -60.379656
# 4      237.159818 -25.033311     32.775376   89.284813  31.535417 -60.379656
# ...           ...        ...           ...         ...        ...        ...
# 29051  237.159818 -25.033311     32.775376   89.284813  31.535417 -60.379656
# 29052  237.159818 -25.033311     32.775376   89.284813  31.535417 -60.379656
# 29053  237.159818 -25.033311     32.775376   89.284813  31.535417 -60.379656
# 29054  237.159818 -25.033311     32.775376   89.284813  31.535417 -60.379656
# 29055  237.159818 -25.033311     32.775376   89.284813  31.535417 -60.379656
#
# [29056 rows x 65 columns]

# %%
dfobs['fiveSigmaDepth']
# Out:
# 0        24.071162
# 1        24.071162
# 2        24.071162
# 3        24.071162
# 4        24.071162
#            ...
# 29051    24.071162
# 29052    24.071162
# 29053    24.071162
# 29054    24.071162
# 29055    24.071162
# Name: fiveSigmaDepth, Length: 29056, dtype: float64

# %%
fig, ax = plt.subplots(1, figsize=(10,10))
ax.scatter(dfobs['fieldRA']-dfobs['AstRA(deg)'],dfobs['fieldDec']-dfobs['AstDec(deg)'], s=0.1, c=dfobs['fiveSigmaDepth'].values)
ax.set_ylabel('distance from field centre RA (deg)')
ax.set_xlabel('distance from field centre Dec (deg)')
# Out:
# Text(0.5, 0, 'distance from field centre Dec (deg)')

# %% [markdown]
# In the above plot, the points have been shaded according to their limiting magnitude.
#
# Now we apply the effects of vignetting and replot.

# %%
dfobs['fiveSigmaDepthAtSource'] = vignettingEffects(dfobs)

# %%
fig, ax = plt.subplots(1, figsize=(10,10))
ax.scatter(dfobs['fieldRA']-dfobs['AstRA(deg)'],dfobs['fieldDec']-dfobs['AstDec(deg)'], s=0.1, c=dfobs['fiveSigmaDepthAtSource'].values)
ax.set_ylabel('distance from field centre RA (deg)')
ax.set_xlabel('distance from field centre Dec (deg)')
# Out:
# Text(0.5, 0, 'distance from field centre Dec (deg)')

# %% [markdown]
# The effects of vignetting can thus be seen.
